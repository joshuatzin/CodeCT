# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

#Promedios horarios
df00=pd.read_csv('datos.csv', usecols = [*range(1, 13)]).mean(axis=1)
df01=pd.read_csv('datos.csv', usecols = [*range(13, 25)]).mean(axis=1)
df02=pd.read_csv('datos.csv', usecols = [*range(25, 37)]).mean(axis=1)
df03=pd.read_csv('datos.csv', usecols = [*range(37, 49)]).mean(axis=1)
df04=pd.read_csv('datos.csv', usecols = [*range(49, 61)]).mean(axis=1)
df05=pd.read_csv('datos.csv', usecols = [*range(61, 73)]).mean(axis=1)
df06=pd.read_csv('datos.csv', usecols = [*range(73, 85)]).mean(axis=1)
df07=pd.read_csv('datos.csv', usecols = [*range(85, 97)]).mean(axis=1)
df08=pd.read_csv('datos.csv', usecols = [*range(97, 109)]).mean(axis=1)
df09=pd.read_csv('datos.csv', usecols = [*range(109, 121)]).mean(axis=1)
df10=pd.read_csv('datos.csv', usecols = [*range(121, 133)]).mean(axis=1)
df11=pd.read_csv('datos.csv', usecols = [*range(133, 145)]).mean(axis=1)
df12=pd.read_csv('datos.csv', usecols = [*range(145, 157)]).mean(axis=1)
df13=pd.read_csv('datos.csv', usecols = [*range(157, 169)]).mean(axis=1)
df14=pd.read_csv('datos.csv', usecols = [*range(169, 181)]).mean(axis=1)
df15=pd.read_csv('datos.csv', usecols = [*range(181, 193)]).mean(axis=1)
df16=pd.read_csv('datos.csv', usecols = [*range(193, 205)]).mean(axis=1)
df17=pd.read_csv('datos.csv', usecols = [*range(205, 217)]).mean(axis=1)
df18=pd.read_csv('datos.csv', usecols = [*range(217, 229)]).mean(axis=1)
df19=pd.read_csv('datos.csv', usecols = [*range(229, 241)]).mean(axis=1)
df20=pd.read_csv('datos.csv', usecols = [*range(241, 253)]).mean(axis=1)
df21=pd.read_csv('datos.csv', usecols = [*range(253, 265)]).mean(axis=1)
df22=pd.read_csv('datos.csv', usecols = [*range(265, 277)]).mean(axis=1)
df23=pd.read_csv('datos.csv', usecols = [*range(277, 289)]).mean(axis=1)

#Diámetro en log
x=pd.read_csv('datos.csv', usecols = [0])

plt.plot(x,df00,label='00:00')
plt.plot(x,df01,label='01:00')
plt.plot(x,df02,label='02:00')
plt.plot(x,df03,label='03:00')
plt.plot(x,df04,label='04:00')
plt.plot(x,df05,label='05:00')
plt.plot(x,df06,label='06:00')
plt.plot(x,df07,label='07:00')
plt.plot(x,df08,label='08:00')
plt.plot(x,df09,label='09:00')
plt.plot(x,df10,label='10:00')
plt.plot(x,df11,label='11:00')
plt.plot(x,df12,label='12:00')
plt.plot(x,df13,label='13:00')
plt.plot(x,df14,label='14:00')
plt.plot(x,df15,label='15:00')
plt.plot(x,df16,label='16:00')
plt.plot(x,df17,label='17:00')
plt.plot(x,df18,label='18:00')
plt.plot(x,df19,label='19:00')
plt.plot(x,df20,label='20:00')
plt.plot(x,df21,label='21:00')
plt.plot(x,df22,label='22:00')
plt.plot(x,df23,label='23:00')


plt.xlabel('Diámetro [nm]')
plt.ylabel('Distribución (dN/dlogDp) [cm-3]')
plt.title('Distribución de tamaño de partículas 29.10.16')
plt.ylim((0,50000))
plt.legend(fontsize='xx-small')
plt.grid(True)
#plt.xscale('log')
plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#Promedios horarios
df01=pd.read_csv('datos.csv', usecols = [*range(13, 25)]).mean(axis=1)

#Diámetro en log
x=pd.read_csv('datos.csv', usecols = [0])

plt.plot(x,df01)
plt.xlabel('Diámetro [nm]')
plt.ylabel('Distribución (dN/dlogDp) [cm-3]')
plt.ylim((0,50000))
plt.title('Distribución de tamaño de partículas 23:00 hrs.')
plt.grid(True)
#plt.xscale('log')
plt.show()
