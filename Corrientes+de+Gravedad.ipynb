# %% [markdown]
# # Ejercicio 1. Serie de tiempo de la temperatura

# %%
import matplotlib.pyplot as plt
import numpy as np

#Serie de tiempo
t=np.arange(1,120,1)

#Datos de temperatura
T=np.loadtxt('temp_sensor1_exp2.txt')
T2=np.loadtxt('temp_sensor2_exp2.txt')

plt.plot(t,T,color='r')
plt.plot(t,T2,color='b')
plt.xlabel("Tiempo [s]")
plt.title("Serie de tiempo de temperatura")
plt.ylabel("Temperatura[°C]")
plt.grid(True)
plt.show()

# %% [markdown]
# # Ejercicio 2. Serie de tiempo de la salinidad

# %%
import matplotlib.pyplot as plt
import numpy as np

#Serie de tiempo
t=np.arange(0,112,1)

#Datos de salinidad (transformados a densidad)

S=np.loadtxt('fgl_2_calibratelimpio.txt')
S1=S[:,1]
S2=S[:,2]

plt.plot(t,S1,color='r')
plt.plot(t,S2,color='b')
plt.xlabel("Tiempo [s]")
plt.title("Serie de tiempo de densidad (datos de salinidad)")
plt.ylabel("Densidad [kg/m³]")
plt.grid(True)
plt.show()

# %% [markdown]
# # Ejercicio 3. Convertir temperatura a densidad

# %%
import matplotlib.pyplot as plt
import numpy as np

a=-7*(10**-4)
p1=998.9
t=np.loadtxt('temp_sensor1_exp2.txt')
T2=np.loadtxt('temp_sensor2_exp2.txt')

for i in range (1,117):
    tuno=(p1*(1-a*(t[i+1]-t[i])))
    tdos=(p1*(1-a*(T2[i+1]-T2[i])))
   

j=np.arange(1,117,1)

tu=np.loadtxt('densidadt1.txt')
td=np.loadtxt('densidadt2.txt')

plt.plot(j,tu,color='r')
plt.plot(j,td,color='b')
plt.xlabel("Tiempo [s]")
plt.title("Serie de tiempo de densidad (datos de temperatura)")
plt.ylabel("Densidad [kg/m³]")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches
from pylab import *

#Función para dos ejes verticales
def two_scales(ax1,time,data1,data2,c1,c2):
    ax2=ax1.twinx()
    ax1.plot(time,data1,color=c1)
    ax1.set_xlabel('Tiempo[s]')
    ax1.set_ylabel('Temperatura [°C]')
    
    ax2.plot(time,data2,color=c2)
    ax2.set_ylabel('Densidad (kg/m³)')
    return ax1, ax2


# Serie de tiempo
t=np.arange(0,112,1)

#Temperatura
T=np.loadtxt('temp_sensor1_exp2_111.txt')


#Salinidad (densidad)
S=np.loadtxt('fgl_2_calibratelimpio.txt')
a=S[:,2]


#Generando la gráfica
figure, ax=plt.subplots()
ax1,ax2=two_scales(ax,t,T,a,'r','b')
ax.set_title('Serie de tiempo')
ax.grid(True)
figure.set_dpi(160) #Tamaño de la imagen



def color_y_axis(ax, color):
    for t in ax.get_yticklabels():
        t.set_color(color)
    return None
color_y_axis(ax1, 'r')
color_y_axis(ax2, 'b')

plt.legend(bbox_to_anchor=(1.1, 1), loc=3, borderaxespad=0.)

plt.show()
# Out:
# C:\Users\Usuario\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
